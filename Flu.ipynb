# %% [markdown]
# ## Load in Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read in excel workbook and separate sheets

# %%
Flu_Workbook = pd.ExcelFile('C:/Users/sglov/Desktop/Final Project/Death Totals.xlsx')
Flu_Workbook

# %%
Flu_Sheet_Names = Flu_Workbook.sheet_names
Flu_Sheet_Names
# Out:
# ['COVID-19 Deaths', 'FluDeaths19-20', 'Flu Deaths 2018']

# %%
FluTotals = Flu_Workbook.parse('FluDeaths19-20')
FluTotals
# Out:
#                                            Unnamed: 0 Symptomatic Illnesses  \
# 0                                           Age group              Estimate
# 1                                             0-4 yrs               4291677
# 2                                            5-17 yrs               8214257
# 3                                           18-49 yrs              15325708
# 4                                           50-64 yrs               8416702
# 5                                             65+ yrs               1946161
# 6                                            All ages              38194505
# 7   Table 2: Estimated rates of influenza-associat...                   NaN
# 8                                                 NaN          Illness rate
# 9                                           Age group              Estimate
# 10                                            0-4 yrs               21922.4
# ...

# %% [markdown]
# ## Drop Unnecessary Rows

# %%
FluTotals2 = FluTotals.drop(FluTotals.index[[0, 9, 15, 16]])
FluTotals2.head()
# Out:
#   Unnamed: 0 Symptomatic Illnesses                Unnamed: 2 Medical Visits  \
# 1    0-4 yrs               4291677    (3,065,436, 8,247,015)        2875424
# 2   5-17 yrs               8214257  (6,551,246, 11,351,951))        4271413
# 3  18-49 yrs              15325708  (11,798,086, 22,121,677)        5670512
# 4  50-64 yrs               8416702  (6,918,420, 10,835,295))        3619182
# 5    65+ yrs               1946161    (1,480,075, 2,883,659)        1089850
#
#                Unnamed: 4 Hospitalizations          Unnamed: 6 Deaths  \
# 1  (2,021,018, 5,544,822)            29920    (21,371, 57,495)    254
# 2  (3,315,969, 6,011,703)            22523    (17,963, 31,126)    180
# 3  (4,214,299, 8,383,456)            86023   (66,223, 124,169)   2669
# 4  (2,832,003, 4,780,110)            89257   (73,368, 114,905)   5133
# 5    (797,945, 1,621,738)           176924  (134,552, 262,151)  13673
#
#          Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# ...

# %% [markdown]
# ## Drop Unnecessary Columns

# %%
FluTotals2.drop(FluTotals2.columns[[2, 4, 6, 8, 9, 10, 11]], axis = 1, inplace = True)

# %%
FluTotals2
# Out:
#                                            Unnamed: 0 Symptomatic Illnesses  \
# 1                                             0-4 yrs               4291677
# 2                                            5-17 yrs               8214257
# 3                                           18-49 yrs              15325708
# 4                                           50-64 yrs               8416702
# 5                                             65+ yrs               1946161
# 6                                            All ages              38194505
# 7   Table 2: Estimated rates of influenza-associat...                   NaN
# 8                                                 NaN          Illness rate
# 10                                            0-4 yrs               21922.4
# 11                                           5-17 yrs               15364.5
# 12                                          18-49 yrs               11088.2
# ...

# %% [markdown]
# ## Subset each data table into their own

# %%
FluTotals2.reset_index(drop=True, inplace=True)
FluTotals2
# Out:
#                                            Unnamed: 0 Symptomatic Illnesses  \
# 0                                             0-4 yrs               4291677
# 1                                            5-17 yrs               8214257
# 2                                           18-49 yrs              15325708
# 3                                           50-64 yrs               8416702
# 4                                             65+ yrs               1946161
# 5                                            All ages              38194505
# 6   Table 2: Estimated rates of influenza-associat...                   NaN
# 7                                                 NaN          Illness rate
# 8                                             0-4 yrs               21922.4
# 9                                            5-17 yrs               15364.5
# 10                                          18-49 yrs               11088.2
# ...

# %%
FluTotalsAll = FluTotals2[:6]
FluTotalsAll
# Out:
#   Unnamed: 0 Symptomatic Illnesses Medical Visits Hospitalizations Deaths
# 0    0-4 yrs               4291677        2875424            29920    254
# 1   5-17 yrs               8214257        4271413            22523    180
# 2  18-49 yrs              15325708        5670512            86023   2669
# 3  50-64 yrs               8416702        3619182            89257   5133
# 4    65+ yrs               1946161        1089850           176924  13673
# 5   All ages              38194505       17526381           404646  21909

# %%
FluTotalsRate = FluTotals2[-5:]
FluTotalsRate
# Out:
#    Unnamed: 0 Symptomatic Illnesses Medical Visits Hospitalizations Deaths
# 8     0-4 yrs               21922.4          14688            152.8    1.3
# 9    5-17 yrs               15364.5         7989.6             42.1    0.3
# 10  18-49 yrs               11088.2         4102.6             62.2    1.9
# 11  50-64 yrs               13375.6         5751.5            141.8    8.2
# 12    65+ yrs                3600.1         2016.1            327.3   25.3

# %% [markdown]
# ## Rename Columns in each table

# %%
FluTotalsRate
# Out:
#    Unnamed: 0 Symptomatic Illnesses Medical Visits Hospitalizations Deaths
# 8     0-4 yrs               21922.4          14688            152.8    1.3
# 9    5-17 yrs               15364.5         7989.6             42.1    0.3
# 10  18-49 yrs               11088.2         4102.6             62.2    1.9
# 11  50-64 yrs               13375.6         5751.5            141.8    8.2
# 12    65+ yrs                3600.1         2016.1            327.3   25.3

# %%
FluTotalsAll
# Out:
#   Unnamed: 0 Symptomatic Illnesses Medical Visits Hospitalizations Deaths
# 0    0-4 yrs               4291677        2875424            29920    254
# 1   5-17 yrs               8214257        4271413            22523    180
# 2  18-49 yrs              15325708        5670512            86023   2669
# 3  50-64 yrs               8416702        3619182            89257   5133
# 4    65+ yrs               1946161        1089850           176924  13673
# 5   All ages              38194505       17526381           404646  21909

# %%
FluTotalsRate.rename(columns={'Unnamed: 0' : 'Age Group', 'Symptomatic Illnesses' : 'Illness Rate', 'Medical Visits' : 'Medical Visit Rate', 'Hospitalizations' : 'Hospitalization rate', 'Deaths' : 'Mortality rate'}, inplace=True)
FluTotalsRate
# Out:
# C:\Users\sglov\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     Age Group Illness Rate Medical Visit Rate Hospitalization rate  \
# 8     0-4 yrs      21922.4              14688                152.8
# 9    5-17 yrs      15364.5             7989.6                 42.1
# 10  18-49 yrs      11088.2             4102.6                 62.2
# 11  50-64 yrs      13375.6             5751.5                141.8
# 12    65+ yrs       3600.1             2016.1                327.3
#
#    Mortality rate
# 8             1.3
# 9             0.3
# 10            1.9
# 11            8.2
# 12           25.3

# %%
FluTotalsAll.rename(columns={'Unnamed: 0' : 'Age Group'}, inplace=True)
FluTotalsAll
# Out:
# C:\Users\sglov\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    Age Group Symptomatic Illnesses Medical Visits Hospitalizations Deaths
# 0    0-4 yrs               4291677        2875424            29920    254
# 1   5-17 yrs               8214257        4271413            22523    180
# 2  18-49 yrs              15325708        5670512            86023   2669
# 3  50-64 yrs               8416702        3619182            89257   5133
# 4    65+ yrs               1946161        1089850           176924  13673
# 5   All ages              38194505       17526381           404646  21909

# %% [markdown]
# ## Reset Index

# %%
FluTotalsAll.reset_index(drop=True, inplace=True)
FluTotalsAll
# Out:
#    Age Group Symptomatic Illnesses Medical Visits Hospitalizations Deaths
# 0    0-4 yrs               4291677        2875424            29920    254
# 1   5-17 yrs               8214257        4271413            22523    180
# 2  18-49 yrs              15325708        5670512            86023   2669
# 3  50-64 yrs               8416702        3619182            89257   5133
# 4    65+ yrs               1946161        1089850           176924  13673
# 5   All ages              38194505       17526381           404646  21909

# %%
FluTotalsRate.reset_index(drop=True, inplace=True)
FluTotalsRate
# Out:
#    Age Group Illness Rate Medical Visit Rate Hospitalization rate  \
# 0    0-4 yrs      21922.4              14688                152.8
# 1   5-17 yrs      15364.5             7989.6                 42.1
# 2  18-49 yrs      11088.2             4102.6                 62.2
# 3  50-64 yrs      13375.6             5751.5                141.8
# 4    65+ yrs       3600.1             2016.1                327.3
#
#   Mortality rate
# 0            1.3
# 1            0.3
# 2            1.9
# 3            8.2
# 4           25.3

# %%
FluTotalsAll
# Out:
#    Age Group Symptomatic Illnesses Medical Visits Hospitalizations Deaths
# 0    0-4 yrs               4291677        2875424            29920    254
# 1   5-17 yrs               8214257        4271413            22523    180
# 2  18-49 yrs              15325708        5670512            86023   2669
# 3  50-64 yrs               8416702        3619182            89257   5133
# 4    65+ yrs               1946161        1089850           176924  13673
# 5   All ages              38194505       17526381           404646  21909

# %%
FluTotalsRate
# Out:
#    Age Group Illness Rate Medical Visit Rate Hospitalization rate  \
# 0    0-4 yrs      21922.4              14688                152.8
# 1   5-17 yrs      15364.5             7989.6                 42.1
# 2  18-49 yrs      11088.2             4102.6                 62.2
# 3  50-64 yrs      13375.6             5751.5                141.8
# 4    65+ yrs       3600.1             2016.1                327.3
#
#   Mortality rate
# 0            1.3
# 1            0.3
# 2            1.9
# 3            8.2
# 4           25.3
